# %% [markdown]
# #### Step 1 - Imports

# %%
import requests
import pandas as pd

# %% [markdown]
# #### Step 2 - CURL

# %%
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^94^\\^, ^\\^Google',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?1',
    'x-autolist-session-guid': 'c7a7c4fb-647a-4ec9-8ca2-0cca3c316e98',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.61 Mobile Safari/537.36',
    'sec-ch-ua-platform': '^\\^Android^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk0LjAuNDYwNi42MSBTYWZhcmkvNTM3LjM2In0=; client_guid_timestamp=e2a34ace-7a1e-4eeb-b9d6-dfa252f93093.1632775748922; scavenger-a493=...; _sp_ses.8ca5=*; _fbp=fb.1.1632775749601.121831768; _gid=GA1.2.1553323031.1632775750; _ga_152345333=GS1.1.1632775748.1.1.1632775767.0; sp-nuid=7ed13491-978f-47f9-b56a-33adcd1c6141; AMP_TOKEN=^%^24NOT_FOUND; _ga=GA1.2.346312752.1632775750; _gcl_au=1.1.677095760.1632775768; __gads=ID=58259cd1d7d313c8:T=1632775753:S=ALNI_MZHwnQwxvXMXjHheI1tBfXfsY8kgA; cto_bundle=HKTMNl9HT01WR1BGam1iZDI0a2Y3Z0RUZ1lRd1YzdzlRJTJGNmRORHdxQnEyeGJnSTBhN3Z0U0VWNVNwM2x2aldYeHVNMHdKSmIzbFBjOVIlMkZNd3haMXNGSk84TW92SzZKQmJBdUNERnhnZVhOZWtObiUyQmtyRzB5OWh6OGZQTGpqWnZFOW9kWFhVTGxyUjlYeVpncE9vSHolMkJEZXpDZyUzRCUzRA; _gat=1; _sp_id.8ca5=0e0de5b0-d076-41c9-b7f2-76cf0daa097a.1632775749.1.1632775863.1632775749.9d10a8e5-9dd2-4e53-b57e-1d13fbbd4738',
    'if-none-match': 'W/^\\^9b45c42f6c7d269f0e780f8e6d595151^\\^',
}

params = (
    ('make', 'Tesla'),
    ('location', 'San^%^20Francisco,^%^20CA'),
    ('latitude', '37.7749295'),
    ('longitude', '-122.4194155'),
    ('radius', '50'),
    ('page', '1'),
)

response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)

# %% [markdown]
# #### Step 3 - Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4 - Create Json Object

# %%
results_json=response.json()

# %%
results_json
# Out:
# {'total_results_count': 269,
#  'make_model_name': 'Tesla',
#  'trims': [],
#  'ad_info': {'ad_unit': '/19485787/AutoList.com/Search_Results_Page/Tesla',
#   'make': 'Tesla',
#   'model': None,
#   'page_type': 'srp',
#   'cpo': False,
#   'body_style': None,
#   'year': 2022,
#   'age_type': 'new',
#   'app': 'web'},
#  'search_results': [{'available_nationwide': False,
#    'created_at': 1629300535,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/5YJ3E1EAXJF049246',
#    'vdp_url': '/tesla-model+3#vin=5YJ3E1EAXJF049246',
#    'clickoff_url': 'https://www.shift.com/car/c1221468?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 225699234,
#    'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/18/09/17/2018_tesla_model_3-pic-3579849719363342482-1024x768.jpeg',
# ...

# %%
type(results_json)
# Out:
# dict

# %% [markdown]
# #### Step 5 - Output Keys

# %%
results_json.keys()
# Out:
# dict_keys(['total_results_count', 'make_model_name', 'trims', 'ad_info', 'search_results', 'html'])

# %% [markdown]
# #### Step 6 - Find your Data

# %%
#model
#mileage
#year
#dealer name
#price

# %%
results_json['search_results']
# Out:
# [{'available_nationwide': False,
#   'created_at': 1629300535,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/5YJ3E1EAXJF049246',
#   'vdp_url': '/tesla-model+3#vin=5YJ3E1EAXJF049246',
#   'clickoff_url': 'https://www.shift.com/car/c1221468?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 225699234,
#   'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/18/09/17/2018_tesla_model_3-pic-3579849719363342482-1024x768.jpeg',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--zRxwMawz--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/18/09/17/2018_tesla_model_3-pic-3579849719363342482-1024x768.jpeg',
#   'lat': 37.6397,
#   'lon': -122.416,
#   'year': 2018,
#   'make': 'Tesla',
#   'model': 'Model 3',
#   'model_id': 2217,
#   'display_color': '',
#   'price': '$42,450',
# ...

# %%
len(results_json['search_results'])
# Out:
# 20

# %%
result_items=results_json['search_results']

# %%
#starting point for first result
results_json['search_results'][0]
# Out:
# {'available_nationwide': False,
#  'created_at': 1629300535,
#  'recent_price_drop': False,
#  'is_hot': False,
#  'href_target': '/listings/5YJ3E1EAXJF049246',
#  'vdp_url': '/tesla-model+3#vin=5YJ3E1EAXJF049246',
#  'clickoff_url': 'https://www.shift.com/car/c1221468?utm_source=Autolist&utm_medium=listing&utm_campaign=deeplink',
#  'accepts_leads': True,
#  'open_in_new_window': False,
#  'id': 225699234,
#  'primary_photo_url': 'https://static.cargurus.com/images/forsale/2021/08/18/09/17/2018_tesla_model_3-pic-3579849719363342482-1024x768.jpeg',
#  'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--zRxwMawz--/c_fill,f_auto,q_auto,w_320/https://static.cargurus.com/images/forsale/2021/08/18/09/17/2018_tesla_model_3-pic-3579849719363342482-1024x768.jpeg',
#  'lat': 37.6397,
#  'lon': -122.416,
#  'year': 2018,
#  'make': 'Tesla',
#  'model': 'Model 3',
#  'model_id': 2217,
#  'display_color': '',
#  'price': '$42,450',
#  'price_unformatted': 42450,
# ...

# %%
#mileage
results_json['search_results'][0]['mileage']
# Out:
# '30,924 Miles'

# %%
#model
results_json['search_results'][0]['model']
# Out:
# 'Model 3'

# %%
#year
results_json['search_results'][0]['year']
# Out:
# 2018

# %%
#dealer name
results_json['search_results'][0]['dealer_name']
# Out:
# 'Shift SF - Test Drives Delivered To You'

# %%
#price
results_json['search_results'][0]['price']
# Out:
# '$42,450'

# %% [markdown]
# #### Step 7 - Put everything together - Loop through results and append data inside a list

# %%
model=[]
mileage=[]
year=[]
dealer_name=[]
price=[]

for result in result_items:
    #model
    model.append(result['model'])
    #mileage
    mileage.append(result['mileage'])
    #year
    year.append(result['year'])
    #dealer name
    dealer_name.append(result['dealer_name'])
    #price
    price.append(result['price'])

# %%
len(price)
# Out:
# 20

# %% [markdown]
# #### Step 8 - Pandas Dataframe - Single Page

# %%
tesla_df=pd.DataFrame({'Model':model,'Mileage':mileage,'Year':year,'Dealer name':dealer_name,'Price':price})

# %%
tesla_df
# Out:
#       Model       Mileage  Year                                Dealer name  \
# 0   Model 3  30,924 Miles  2018    Shift SF - Test Drives Delivered To You
# 1   Model 3   9,739 Miles  2020    Shift SF - Test Drives Delivered To You
# 2   Model 3   9,160 Miles  2020    Shift SF - Test Drives Delivered To You
# 3   Model 3  19,632 Miles  2018    Shift SF - Test Drives Delivered To You
# 4   Model 3  39,895 Miles  2018    Shift SF - Test Drives Delivered To You
# 5   Model 3  11,091 Miles  2020    Shift SF - Test Drives Delivered To You
# 6   Model 3  10,867 Miles  2018    Shift SF - Test Drives Delivered To You
# 7   Model 3  26,333 Miles  2018    Shift SF - Test Drives Delivered To You
# 8   Model 3  31,331 Miles  2018  Future Chrysler Dodge Jeep Ram Of Concord
# 9   Model 3  29,417 Miles  2019    Shift SF - Test Drives Delivered To You
# 10  Model 3  41,902 Miles  2019    Shift SF - Test Drives Delivered To You
# ...

# %%
tesla_df.to_excel('tesla_single_page.xlsx',index=False)

# %% [markdown]
# #### Step 9 - Scraping Multiple Pages (here: 5pages to get 100 results)

# %%
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^94^\\^, ^\\^Google',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?1',
    'x-autolist-session-guid': 'c7a7c4fb-647a-4ec9-8ca2-0cca3c316e98',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.61 Mobile Safari/537.36',
    'sec-ch-ua-platform': '^\\^Android^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk0LjAuNDYwNi42MSBTYWZhcmkvNTM3LjM2In0=; client_guid_timestamp=e2a34ace-7a1e-4eeb-b9d6-dfa252f93093.1632775748922; scavenger-a493=...; _sp_ses.8ca5=*; _fbp=fb.1.1632775749601.121831768; _gid=GA1.2.1553323031.1632775750; _ga_152345333=GS1.1.1632775748.1.1.1632775767.0; sp-nuid=7ed13491-978f-47f9-b56a-33adcd1c6141; AMP_TOKEN=^%^24NOT_FOUND; _ga=GA1.2.346312752.1632775750; _gcl_au=1.1.677095760.1632775768; __gads=ID=58259cd1d7d313c8:T=1632775753:S=ALNI_MZHwnQwxvXMXjHheI1tBfXfsY8kgA; cto_bundle=HKTMNl9HT01WR1BGam1iZDI0a2Y3Z0RUZ1lRd1YzdzlRJTJGNmRORHdxQnEyeGJnSTBhN3Z0U0VWNVNwM2x2aldYeHVNMHdKSmIzbFBjOVIlMkZNd3haMXNGSk84TW92SzZKQmJBdUNERnhnZVhOZWtObiUyQmtyRzB5OWh6OGZQTGpqWnZFOW9kWFhVTGxyUjlYeVpncE9vSHolMkJEZXpDZyUzRCUzRA; _gat=1; _sp_id.8ca5=0e0de5b0-d076-41c9-b7f2-76cf0daa097a.1632775749.1.1632775863.1632775749.9d10a8e5-9dd2-4e53-b57e-1d13fbbd4738',
    'if-none-match': 'W/^\\^9b45c42f6c7d269f0e780f8e6d595151^\\^',
}

model=[]
mileage=[]
year=[]
dealer_name=[]
price=[]

for i in range(1,6):

    params = (
        ('make', 'Tesla'),
        ('location', 'San^%^20Francisco,^%^20CA'),
        ('latitude', '37.7749295'),
        ('longitude', '-122.4194155'),
        ('radius', '50'),
        ('page', str(i)),
    )
    
    #response variable for get request

    response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)
    #creating json object
    results_json=response.json()
    
    #result items (20 items for each page)
    result_items=results_json['search_results']
    for result in result_items:
        #model
        model.append(result['model'])
        #mileage
        mileage.append(result['mileage'])
        #year
        year.append(result['year'])
        #dealer name
        dealer_name.append(result['dealer_name'])
        #price
        price.append(result['price'])

# %%
tesla_multiple_df=pd.DataFrame({'Model':model,'Mileage':mileage,'Year':year,'Dealer name':dealer_name,'Price':price})

# %%
tesla_multiple_df
# Out:
#       Model       Mileage  Year                              Dealer name  \
# 0   Model 3  30,924 Miles  2018  Shift SF - Test Drives Delivered To You
# 1   Model 3   9,739 Miles  2020  Shift SF - Test Drives Delivered To You
# 2   Model 3   9,160 Miles  2020  Shift SF - Test Drives Delivered To You
# 3   Model 3  19,632 Miles  2018  Shift SF - Test Drives Delivered To You
# 4   Model 3  39,895 Miles  2018  Shift SF - Test Drives Delivered To You
# ..      ...           ...   ...                                      ...
# 95  Model 3  30,567 Miles  2019                         Lexus Of Fremont
# 96  Model 3  24,974 Miles  2018                             Capitol Ford
# 97  Model 3   6,609 Miles  2019                   Honda Of Stevens Creek
# 98  Model S     861 Miles  2021                          Response Motors
# 99  Model X   3,248 Miles  2020               Specialty Sales Pleasanton
#
#        Price
# 0    $42,450
# 1    $51,450
# 2    $44,950
# 3    $44,500
# 4    $40,950
# ...

# %% [markdown]
# #### Step 10 - Store Results in Excel

# %%
tesla_multiple_df.to_excel('tesla_multiple_pages.xlsx',index=False)
